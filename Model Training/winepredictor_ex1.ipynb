# %%
import os
import gc
import numpy as np
import pandas as pd
import pickle
from keras.layers import Dense, Input, Dropout,Flatten,MaxPooling1D,SpatialDropout2D,SpatialDropout1D
from keras.layers import Conv1D, MaxPooling2D,BatchNormalization,Conv2D
from keras.models import Model
from keras.models import Sequential
from keras import optimizers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras import regularizers
from sklearn.preprocessing import Normalizer

# %%
with open('pca_500_x_pd','rb') as f:
    X = pickle.load(f)
with open('pca_y_pd','rb') as f:
    Y = pickle.load(f)

# %%
nor = Normalizer()

# %%
nor.fit(X)
# Out:
# Normalizer(copy=True, norm='l2')

# %%
X = nor.transform(X)

# %%
X.shape
# Out:
# (120975, 500)

# %%
Y.shape
# Out:
# (120975,)

# %%
learning_rate=0.0001
decay=0.0000001
momentum=0.99

dropout_rate = 0.15

rglrzr = regularizers.l2(0.0003)

# %%
model = Sequential()


model.add(Dense(500,activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(Dropout(rate=dropout_rate))

model.add(Dense(500,activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(Dropout(rate=dropout_rate))

model.add(Dense(100,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(rate=dropout_rate))

model.add(Dense(20,activation='relu'))
model.add(Dense(1))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 500)               250500
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 500)               2000
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 500)               250500
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 500)               2000
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 100)               50100
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 100)               400
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 20)                2020
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 557,541
# Trainable params: 555,341
# Non-trainable params: 2,200
# _________________________________________________________________

# %%
optimizer = optimizers.adam(lr=learning_rate,decay=decay)
model.compile(loss='mse',
              optimizer=optimizer, 
              metrics=['mae','mse'])

# %%
cb=[]

#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=3, verbose=0, mode='auto')
early_stopping = EarlyStopping(monitor='acc', min_delta=0, patience=30, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

#cb.append(reduce_lr)
cb.append(early_stopping)

# %%
history=model.fit(X, Y,
          batch_size=256,
          epochs=30,
          verbose=1,
          callbacks=cb,
          validation_split=0.3,
          shuffle=True)
# Out:
# Train on 84682 samples, validate on 36293 samples
# Epoch 1/30
# 84682/84682 [==============================] - 9s 112us/step - loss: 2437.2195 - mean_absolute_error: 30.8899 - mean_squared_error: 2437.2195 - val_loss: 2083.3236 - val_mean_absolute_error: 26.3604 - val_mean_squared_error: 2083.3236
# Epoch 2/30
#  1792/84682 [..............................] - ETA: 7s - loss: 1601.1183 - mean_absolute_error: 27.9114 - mean_squared_error: 1601.1183
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:569: RuntimeWarning: Early stopping conditioned on metric `acc` which is not available. Available metrics are: val_loss,val_mean_absolute_error,val_mean_squared_error,loss,mean_absolute_error,mean_squared_error
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 84682/84682 [==============================] - 8s 92us/step - loss: 1857.7760 - mean_absolute_error: 24.3771 - mean_squared_error: 1857.7760 - val_loss: 1727.8937 - val_mean_absolute_error: 21.8354 - val_mean_squared_error: 1727.8937
# Epoch 3/30
# 84682/84682 [==============================] - 8s 92us/step - loss: 1454.6922 - mean_absolute_error: 19.5900 - mean_squared_error: 1454.6922 - val_loss: 1437.2835 - val_mean_absolute_error: 17.8026 - val_mean_squared_error: 1437.2835
# Epoch 4/30
# 84682/84682 [==============================] - 8s 93us/step - loss: 1216.0283 - mean_absolute_error: 16.5463 - mean_squared_error: 1216.0283 - val_loss: 1258.4669 - val_mean_absolute_error: 15.2370 - val_mean_squared_error: 1258.4669
# Epoch 5/30
# 84682/84682 [==============================] - 8s 93us/step - loss: 1076.6209 - mean_absolute_error: 14.8319 - mean_squared_error: 1076.6209 - val_loss: 1157.9705 - val_mean_absolute_error: 13.6392 - val_mean_squared_error: 1157.9705
# Epoch 6/30
# 84682/84682 [==============================] - 8s 92us/step - loss: 980.9653 - mean_absolute_error: 13.6492 - mean_squared_error: 980.9653 - val_loss: 1138.3311 - val_mean_absolute_error: 13.4313 - val_mean_squared_error: 1138.3311
# Epoch 7/30
# 84682/84682 [==============================] - 8s 92us/step - loss: 886.4205 - mean_absolute_error: 13.0616 - mean_squared_error: 886.4205 - val_loss: 1060.0235 - val_mean_absolute_error: 12.4818 - val_mean_squared_error: 1060.0235
# Epoch 8/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 807.9862 - mean_absolute_error: 12.4774 - mean_squared_error: 807.9862 - val_loss: 1047.2384 - val_mean_absolute_error: 12.0990 - val_mean_squared_error: 1047.2384
# Epoch 9/30
# 84682/84682 [==============================] - 8s 91us/step - loss: 739.7741 - mean_absolute_error: 11.9593 - mean_squared_error: 739.7741 - val_loss: 1050.4144 - val_mean_absolute_error: 11.6707 - val_mean_squared_error: 1050.4144
# Epoch 10/30
# 84682/84682 [==============================] - 8s 91us/step - loss: 690.3190 - mean_absolute_error: 11.5476 - mean_squared_error: 690.3190 - val_loss: 1037.9023 - val_mean_absolute_error: 11.5394 - val_mean_squared_error: 1037.9023
# Epoch 11/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 648.7528 - mean_absolute_error: 11.4188 - mean_squared_error: 648.7528 - val_loss: 1036.0545 - val_mean_absolute_error: 11.3558 - val_mean_squared_error: 1036.0545
# Epoch 12/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 631.3112 - mean_absolute_error: 11.2548 - mean_squared_error: 631.3112 - val_loss: 1037.0309 - val_mean_absolute_error: 11.2696 - val_mean_squared_error: 1037.0309
# Epoch 13/30
# 84682/84682 [==============================] - 8s 91us/step - loss: 597.3569 - mean_absolute_error: 11.0391 - mean_squared_error: 597.3569 - val_loss: 1055.9069 - val_mean_absolute_error: 11.3484 - val_mean_squared_error: 1055.9069
# Epoch 14/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 564.7425 - mean_absolute_error: 10.8759 - mean_squared_error: 564.7425 - val_loss: 1030.8542 - val_mean_absolute_error: 11.2553 - val_mean_squared_error: 1030.8542
# Epoch 15/30
# 84682/84682 [==============================] - 8s 91us/step - loss: 546.5997 - mean_absolute_error: 10.7581 - mean_squared_error: 546.5997 - val_loss: 1030.0831 - val_mean_absolute_error: 11.1742 - val_mean_squared_error: 1030.0831
# Epoch 16/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 545.3670 - mean_absolute_error: 10.6738 - mean_squared_error: 545.3670 - val_loss: 1048.2404 - val_mean_absolute_error: 11.1547 - val_mean_squared_error: 1048.2404
# Epoch 17/30
# 84682/84682 [==============================] - 8s 92us/step - loss: 533.5546 - mean_absolute_error: 10.5839 - mean_squared_error: 533.5546 - val_loss: 1016.1263 - val_mean_absolute_error: 11.1493 - val_mean_squared_error: 1016.1263
# Epoch 18/30
# 84682/84682 [==============================] - 8s 91us/step - loss: 511.1719 - mean_absolute_error: 10.4611 - mean_squared_error: 511.1719 - val_loss: 1027.5731 - val_mean_absolute_error: 11.1264 - val_mean_squared_error: 1027.5731
# Epoch 19/30
# 84682/84682 [==============================] - 8s 91us/step - loss: 502.5327 - mean_absolute_error: 10.4410 - mean_squared_error: 502.5327 - val_loss: 1026.7283 - val_mean_absolute_error: 11.0515 - val_mean_squared_error: 1026.7283
# Epoch 20/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 486.0937 - mean_absolute_error: 10.3220 - mean_squared_error: 486.0937 - val_loss: 1047.8066 - val_mean_absolute_error: 11.0435 - val_mean_squared_error: 1047.8066
# Epoch 21/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 468.8661 - mean_absolute_error: 10.2045 - mean_squared_error: 468.8661 - val_loss: 1057.2247 - val_mean_absolute_error: 11.1087 - val_mean_squared_error: 1057.2247
# Epoch 22/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 453.0367 - mean_absolute_error: 10.1283 - mean_squared_error: 453.0367 - val_loss: 1027.6389 - val_mean_absolute_error: 11.0350 - val_mean_squared_error: 1027.6389
# Epoch 23/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 459.1318 - mean_absolute_error: 10.1287 - mean_squared_error: 459.1318 - val_loss: 1035.9474 - val_mean_absolute_error: 11.0552 - val_mean_squared_error: 1035.9474
# Epoch 24/30
# 84682/84682 [==============================] - 8s 89us/step - loss: 452.5476 - mean_absolute_error: 10.0647 - mean_squared_error: 452.5476 - val_loss: 1034.8173 - val_mean_absolute_error: 10.9825 - val_mean_squared_error: 1034.8173
# Epoch 25/30
# 84682/84682 [==============================] - 8s 89us/step - loss: 451.9421 - mean_absolute_error: 9.9886 - mean_squared_error: 451.9421 - val_loss: 1032.9720 - val_mean_absolute_error: 10.9762 - val_mean_squared_error: 1032.9720
# Epoch 26/30
# 84682/84682 [==============================] - 7s 88us/step - loss: 437.0790 - mean_absolute_error: 9.8508 - mean_squared_error: 437.0790 - val_loss: 1061.3967 - val_mean_absolute_error: 11.0064 - val_mean_squared_error: 1061.3967
# Epoch 27/30
# 84682/84682 [==============================] - 8s 89us/step - loss: 425.1700 - mean_absolute_error: 9.8159 - mean_squared_error: 425.1700 - val_loss: 1027.3192 - val_mean_absolute_error: 10.9636 - val_mean_squared_error: 1027.3192
# Epoch 28/30
# 84682/84682 [==============================] - 8s 90us/step - loss: 421.9305 - mean_absolute_error: 9.7900 - mean_squared_error: 421.9305 - val_loss: 1036.1498 - val_mean_absolute_error: 10.9359 - val_mean_squared_error: 1036.1498
# Epoch 29/30
# 84682/84682 [==============================] - 8s 89us/step - loss: 413.7556 - mean_absolute_error: 9.7278 - mean_squared_error: 413.7556 - val_loss: 1013.5401 - val_mean_absolute_error: 10.9471 - val_mean_squared_error: 1013.5401
# Epoch 30/30
# 84682/84682 [==============================] - 8s 89us/step - loss: 412.0006 - mean_absolute_error: 9.6382 - mean_squared_error: 412.0006 - val_loss: 1015.9356 - val_mean_absolute_error: 10.9583 - val_mean_squared_error: 1015.9356

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model mae')
plt.ylabel('mae')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Model mse')
plt.ylabel('mse')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
